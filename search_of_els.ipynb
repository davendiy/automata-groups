# %%
# %load_ext autoreload
# %autoreload 2

from multiprocessing import Value, Process
from src.source2 import *
import time

# %%
done1 = Value('f', 0)
done2 = Value('f', 0)
done3 = Value('f', 0)

memory1 = Value('i', 0)
memory2 = Value('i', 0)
memory3 = Value('i', 0)


def info():
    while True:
        print('\r', end='')
        memory = memory1.value + memory2.value + memory3.value
        print(f"[*] done1: {str(done1.value)[:5]}%;  "
              f"done2: {str(done2.value)[:5]}%; "
              f"done3: {str(done3.value)[:5]}%; "
              f"memory usage: {memory / CHUNK * 100}%;     ", end='')
        time.sleep(1)

        if done1.value >= 99.999 and done2.value >= 99.999 \
                and done3.value >= 99.999:
            break


def task(n, done, memory):
    process = psutil.Process(os.getpid())
    
    all_amount = 3 * 2 ** (n - 1)
    res = []
        
    i = 0
    try:
        print(f"[!!!] Start the process for n={n}")
        for el in permute('abc', repeat=n):

            tmp_el = from_string(el)
            if tmp_el.permutation != TRIVIAL_PERM and all([child.is_trivial() for child in tmp_el]):
                print(tmp_el)
                res.append(tmp_el)
            i += 1
            with done.get_lock():
                done.value = i / all_amount * 100
            with memory.get_lock():
                memory.value = process.memory_info()[0]

    except Exception as exc:
        print("[ERROR]", exc.with_traceback())
        with open(f'seach_results_n{n}.txt', 'w') as file:
            file.write(str(res))                 
            

Process(target=task, args=(20, done1, memory1), daemon=True).start()
Process(target=task, args=(21, done2, memory2), daemon=True).start()
Process(target=task, args=(22, done3, memory3), daemon=True).start()

obs = Process(target=info)
obs.start()
obs.join()
# Out:
# [!!!] Start the process for n=20
# [!!!] Start the process for n=21
# [!!!] Start the process for n=22
# Process Process-1:
# Process Process-2:
# Process Process-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-5aa383587185>", line 18, in info
#     time.sleep(1)
# KeyboardInterrupt
# [*] done1: 0.204%;  done2: 0.091%; done3: 0.055%; memory usage: 75.11924743652344%;
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-5aa383587185>", line 36, in task
#     tmp_el = from_string(el)
#   File "<ipython-input-3-5aa383587185>", line 36, in task
#     tmp_el = from_string(el)
#   File "/files/univer/automata-groups/src/source2.py", line 444, in from_string
#     res *= AutomataGroupElement.from_cache(el)
#   File "/files/univer/automata-groups/src/source2.py", line 444, in from_string
#     res *= AutomataGroupElement.from_cache(el)
#   File "/files/univer/automata-groups/src/source2.py", line 429, in __mul__
#     return AutomataGroupElement(res_name, res_permutation, res_children)
#   File "/files/univer/automata-groups/src/source2.py", line 336, in __init__
#     self.add_child(child)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5aa383587185> in <module>
#      56 obs = Process(target=info)
#      57 obs.start()
# ---> 58 obs.join()
#
# /usr/lib/python3.6/multiprocessing/process.py in join(self, timeout)
#     122         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     123         assert self._popen is not None, 'can only join a started process'
# --> 124         res = self._popen.wait(timeout)
#     125         if res is not None:
#     126             _children.discard(self)
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in wait(self, timeout)
#      48                     return None
#      49             # This shouldn't block if wait() returned successfully.
# ---> 50             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      51         return self.returncode
#      52
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in poll(self, flag)
#      26             while True:
#      27                 try:
# ---> 28                     pid, sts = os.waitpid(self.pid, flag)
#      29                 except OSError as e:
#      30                     # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
#   File "/files/univer/automata-groups/src/source2.py", line 423, in __mul__
#     self_child = self[i ^ other.permutation]  # type: AutomataGroupElement
#   File "/files/univer/automata-groups/src/source2.py", line 373, in __getitem__
#     res_tree.children, res_tree.simplify)
#   File "/files/univer/automata-groups/src/source2.py", line 348, in add_child
#     local_child = child.tree.copy()
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 336, in __init__
#     self.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 346, in add_child
#     local_child = child.copy()
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
# KeyboardInterrupt
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 295, in __copy__
#     self.reverse, self.simplify)
# KeyboardInterrupt
# Process Process-3:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-5aa383587185>", line 36, in task
#     tmp_el = from_string(el)
#   File "/files/univer/automata-groups/src/source2.py", line 444, in from_string
#     res *= AutomataGroupElement.from_cache(el)
#   File "/files/univer/automata-groups/src/source2.py", line 423, in __mul__
#     self_child = self[i ^ other.permutation]  # type: AutomataGroupElement
#   File "/files/univer/automata-groups/src/source2.py", line 373, in __getitem__
#     res_tree.children, res_tree.simplify)
#   File "/files/univer/automata-groups/src/source2.py", line 336, in __init__
#     self.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 346, in add_child
#     local_child = child.copy()
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 300, in __copy__
#     res.add_child(child)
#   File "/files/univer/automata-groups/src/source2.py", line 269, in add_child
#     _child = child.copy()       # add only copies of the given trees
#   File "/files/univer/automata-groups/src/source2.py", line 291, in copy
#     return self.__copy__()
#   File "/files/univer/automata-groups/src/source2.py", line 295, in __copy__
#     self.reverse, self.simplify)
#   File "/files/univer/automata-groups/src/source2.py", line 75, in __init__
#     super().__init__(value)
# KeyboardInterrupt
