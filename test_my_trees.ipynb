# %%
from source2 import *
# %matplotlib inline

# %%
test = from_string("abc")
test.show()
# Out:
# /files/univer/automata-groups/source2.py:103: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
(a * b).show()

# %%
(a * a).show(show_full=True)

# %%
tmp = from_string("abcabcabcabcabcabcabcabcabcbcacbaca")
tmp2 = from_string("ababababababababababababababababab")

tmp_inv = from_string("abcabcabcabcabcabcabcabcabcbcacbaca"[::-1])
tmp2_inv = from_string("ababababababababababababababababab"[::-1])
tmp.show(save_filename='tmp.png')

# %%
tmp2.show(save_filename='tmp2.png')

# %%
(tmp * tmp_inv).tree.draw(save_filename='big_trivial.png', y_scale_mul=10, radius=6)

# %%
(tmp * tmp2).tree.draw(save_filename='big_not_trivial.png', y_scale_mul=20, radius=8)
