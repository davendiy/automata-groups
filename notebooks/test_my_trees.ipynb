# %%
from src.source2 import *
# %matplotlib inline

# %%
test = from_string("abc")
test.show()
# Out:
# /files/univer/automata-groups/source2.py:191: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
test.show(show_full=True, lbn=True)

# %%
(a * b).show()

# %%
(a * a).show(show_full=True)

# %%
tmp = from_string("abcabcabcabcabcabcabcabcabcbcacbaca")
tmp2 = from_string("ababababababababababababababababab")

tmp_inv = from_string("abcabcabcabcabcabcabcabcabcbcacbaca"[::-1])
tmp2_inv = from_string("ababababababababababababababababab"[::-1])
tmp.show(save_filename='graphs/tmp.png', lbn=True)

# %%
tmp2.show(save_filename='graphs/tmp2.png', lbn=True)

# %%
(tmp * tmp_inv).show(save_filename='graphs/big_trivial.png', y_scale_mul=10, radius=6, lbn=True)

# %%
(tmp * tmp2).show(save_filename='graphs/big_not_trivial.png', y_scale_mul=20, radius=8, lbn=True)

# %%
(tmp * tmp2 * tmp * tmp2).show(scale=15, y_scale_mul=20, radius=8, lbn=True,
                               save_filename='graphs/very_big_not_trivial.png')

# %%
test = a * b * c
test.show(show_full=True)

# %%
print(test.tree.height(), test.tree.vert_amount(), test.tree.size())
# Out:
# 5 40 16
