# %%
from src.source2 import _generate_H4
_generate_H4()
from src.source2 import *


x = from_string('abag')
x.show()
# Out:
# /files/univer/automata-groups/src/source2.py:204: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
(x ** 3).show(y_scale_mul=10)

# %%
x1 = (x**3)[0]
x1.show()

# %%
x2 = (x1 ** 3)[0]
x2.show()

# %%
x3 = (x2 ** 3)[0]
x3.show()

# %%
x4 = (x3 ** 3)[0]
x4.show()

# %%
x5 = (x4 ** 3)[0]
x5.show()
