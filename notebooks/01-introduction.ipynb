# %%
import sys

if '../' not in sys.path: 
    sys.path.append('../')

# %%
from autogrp import AutomataGroup, AutomataGroupElement

# %%
G = AutomataGroup.generate_H3(apply_reduce_func=True)
G
# Out:
# AutomataGroup H3
# over alphabet {'2', '0', '1'}
# generated by <H3(a = (2)(0 1) (e, e, a)), H3(b = (0 2) (e, b, e)), H3(c = (1 2) (c, e, e))>.

# %%
el = G.random_el(20)
el
# Out:
# H3(bcbabcababcbabcbcaca = (0 2 1) (cacba, baca, aca))

# %%
el.describe()
# Out:
# =======================H3(bcbabcababcbabcbcaca = (0 2 1) (cacba, baca, aca))=======================
# Group:
# AutomataGroup H3
# over alphabet {'2', '0', '1'}
# generated by <H3(a = (2)(0 1) (e, e, a)), H3(b = (0 2) (e, b, e)), H3(c = (1 2) (c, e, e))>.
#
# size:      50
# height:    6
#
# Generation: 0, element: bcbabcababcbabcbcaca
# Generation: 1, element: bcacba
# Generation: 2, element: cacbab
# Found cycle between cacbab and bcacba of length 3.0
#
# is finite: False
# order:     inf
#
# Found cycle
#     start deep:   1
#     end deep:     2
#     start el:     bcacba
#     end el:       cacbab
#     start power:  3
#     end power:    9
#     cycle weight: 3.0
#     full path:    00
#     word with cycle orbit:  0(0)
# ====================================================================================================
